# %%
import pandas as pd
import numpy as np

# %%
cols = ['gameid', 'league', 'year', 'game',
        'patch', 'side', 'position', 'teamname',
        'champion', 'ban1', 'ban2', 'ban3', 'ban4', 'ban5', 
        'gamelength', 'result', 'kills', 'deaths', 
        'assists', 'teamkills','teamdeaths', 'damagetochampions',
        'wardsplaced', 'wardskilled', 'controlwardsbought',
        'totalgold', 'total cs'
        ]

# %%
df_2021 = pd.read_csv(
    './data/2021_LoL_esports_match_data_from_OraclesElixir.csv', usecols=cols)
df_2020 = pd.read_csv(
    './data/2020_LoL_esports_match_data_from_OraclesElixir.csv', usecols=cols)
df_2019 = pd.read_csv(
    './data/2019_LoL_esports_match_data_from_OraclesElixir.csv', usecols=cols)
df_2018 = pd.read_csv(
    './data/2018_LoL_esports_match_data_from_OraclesElixir.csv', usecols=cols)
df_2022 = pd.read_csv(
    './data/2022_LoL_esports_match_data_from_OraclesElixir.csv', usecols=cols)
df_2022.head()
# Out:
#                   gameid  league  year  game  patch  side position
# 0  ESPORTSTMNT01_2690210  LCK CL  2022     1  12.01  Blue      top  \
# 1  ESPORTSTMNT01_2690210  LCK CL  2022     1  12.01  Blue      jng
# 2  ESPORTSTMNT01_2690210  LCK CL  2022     1  12.01  Blue      mid
# 3  ESPORTSTMNT01_2690210  LCK CL  2022     1  12.01  Blue      bot
# 4  ESPORTSTMNT01_2690210  LCK CL  2022     1  12.01  Blue      sup
#
#                    teamname  champion   ban1  ... deaths assists teamkills
# 0  Fredit BRION Challengers  Renekton  Karma  ...      3       2         9  \
# 1  Fredit BRION Challengers  Xin Zhao  Karma  ...      5       6         9
# 2  Fredit BRION Challengers   LeBlanc  Karma  ...      2       3         9
# 3  Fredit BRION Challengers    Samira  Karma  ...      4       2         9
# 4  Fredit BRION Challengers     Leona  Karma  ...      5       6         9
#
#   teamdeaths  damagetochampions  wardsplaced  wardskilled  controlwardsbought
# 0         19            15768.0          8.0          6.0                 5.0  \
# 1         19            11765.0          6.0         18.0                 6.0
# 2         19            14258.0         19.0          7.0                 7.0
# 3         19            11106.0         12.0          6.0                 4.0
# 4         19             3663.0         29.0         14.0                11.0
#
#    totalgold  total cs
# 0      10934     231.0
# 1       9138     148.0
# 2       9715     193.0
# 3      10605     226.0
# 4       6678      42.0
#
# [5 rows x 27 columns]

# %%
df = pd.concat([df_2022, df_2021, df_2020, df_2019, df_2018])

# %% [markdown]
# I only want the professional series games which include:
#
# - LCK
# - LPL
# - LEC
# - LCS
# - LJL
# - PCS
# - VCS
# - LLA
# - LAS

# %%
df['league'].unique()
# Out:
# array(['LCK CL', 'LPL', 'NLC', 'SL', 'Proving Grounds Circuit', 'UL',
#        'PRM', 'LCK', 'LFL', 'LEC', 'LCS', 'LFL2', 'GLL', 'HM', 'ESLOL',
#        'EBL', 'LPLOL', 'PGN', 'LCSA', 'LVP DDH', 'TAL', 'TCL', 'CBLOL',
#        'LCO', 'LHE', 'GL', 'EL', 'CBLOLA', 'LMF', 'VL', 'LLA', 'HC',
#        'LDL', 'LJL', 'PCS', 'VCS', 'UPL', 'LCL', 'NEXO', 'EM', 'LAS',
#        'MSI', 'LJLA', 'CT', 'WCS', 'CDF', 'IC', 'DC', 'KeSPA', 'CU', 'BL',
#        'RCL', 'DL', 'UKLC', 'OTBLX', 'BIG', 'BM', 'UGP', 'GSG', 'HS',
#        'AOL', 'NERD', 'EGL', 'NASG', 'SLO', 'OPL', 'BRCC', 'CK', 'OCS',
#        'Riot', 'MSC', 'NEST', 'LMS', 'LGL', 'EU LCS', 'LLN', 'CLS',
#        'NA LCS', 'TCS', 'LJLCS', 'CIS CL', 'GPL'], dtype=object)

# %%
print(f'Start shape: {df.shape}')
professional_leagues = set('LCK LPL LEC LCS LLA'.split())
df = df[df['league'].isin(professional_leagues)].reset_index(drop=True)
print(f'End shape: {df.shape}')
# Out:
# Start shape: (596762, 27)
# End shape: (107606, 27)

# %%
df.isna().sum()
# Out:
# gameid                   48
# league                    0
# year                      0
# game                      0
# patch                     0
# side                      0
# position                  0
# teamname                  0
# champion              17936
# ban1                     72
# ban2                     42
# ban3                    180
# ban4                    132
# ban5                    318
# gamelength                0
# result                    0
# kills                     0
# deaths                    0
# assists                   0
# teamkills                 0
# teamdeaths                0
# damagetochampions       216
# wardsplaced             216
# wardskilled             216
# controlwardsbought      216
# totalgold                60
# total cs              16518
# dtype: int64

# %% [markdown]
# We need to have champion in the final dataset so we'll remove any rows that dont have a champion

# %%
clean = df.dropna(subset=['champion', 'gameid', 'damagetochampions',
                          'wardsplaced', 'wardskilled', 'controlwardsbought',
                          'totalgold',
                          'total cs' ])
clean.head()
# Out:
#              gameid league  year  game  patch  side position   teamname
# 0  8401-8401_game_1    LPL  2022   1.0  12.01  Blue      top  Oh My God  \
# 1  8401-8401_game_1    LPL  2022   1.0  12.01  Blue      jng  Oh My God
# 2  8401-8401_game_1    LPL  2022   1.0  12.01  Blue      mid  Oh My God
# 3  8401-8401_game_1    LPL  2022   1.0  12.01  Blue      bot  Oh My God
# 4  8401-8401_game_1    LPL  2022   1.0  12.01  Blue      sup  Oh My God
#
#     champion      ban1  ... deaths assists teamkills teamdeaths
# 0       Gwen  Renekton  ...      0       4        13          6  \
# 1  Jarvan IV  Renekton  ...      1      13        13          6
# 2     Syndra  Renekton  ...      0       5        13          6
# 3       Jinx  Renekton  ...      1       6        13          6
# 4   Nautilus  Renekton  ...      4       7        13          6
#
#    damagetochampions  wardsplaced  wardskilled  controlwardsbought  totalgold
# 0            11188.0          7.0          5.0                 3.0     9123.0  \
# 1             4426.0          7.0         10.0                 5.0     9041.0
# 2            12577.0          8.0          2.0                 4.0     9928.0
# 3             9618.0         23.0         12.0                 7.0    10778.0
# 4             2276.0         34.0          4.0                13.0     6598.0
#
#    total cs
# 0     172.0
# 1     145.0
# 2     212.0
# 3     199.0
# 4      22.0
#
# [5 rows x 27 columns]

# %%
clean.isna().sum()
# Out:
# gameid                  0
# league                  0
# year                    0
# game                    0
# patch                   0
# side                    0
# position                0
# teamname                0
# champion                0
# ban1                   60
# ban2                   35
# ban3                  150
# ban4                  110
# ban5                  265
# gamelength              0
# result                  0
# kills                   0
# deaths                  0
# assists                 0
# teamkills               0
# teamdeaths              0
# damagetochampions       0
# wardsplaced             0
# wardskilled             0
# controlwardsbought      0
# totalgold               0
# total cs                0
# dtype: int64

# %% [markdown]
# If banX is N/A, the team simply didn't ban for that slot and we will set it to None

# %%
clean.loc[:, ['ban1', 'ban2', 'ban3', 'ban4', 'ban5']
      ] = clean[['ban1', 'ban2', 'ban3', 'ban4', 'ban5']].fillna('None')
clean.loc[:, ['game']] = clean.loc[:, ['game']].fillna(0)
clean.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Now that we have no NA values, I'm going to build our tabular data
# We want to be able to do the following:
# - Kills per champion
# - Deaths per champion
# - Playrate per champion
# - Gold difference for each team per year
# - Win percentages for each team per year

# %%
clean = clean[clean['year'] < 2023]

# %%
team_year_counts = clean.groupby(['teamname'])['year'].nunique()
team_year_counts = team_year_counts[team_year_counts > 2]
team_greater_2_years = team_year_counts.index

# %%
team_win_percent_by_year = clean[clean['teamname'].isin(team_greater_2_years)].groupby(['year', 'league', 'teamname'])[['result']].mean().reset_index()
team_win_percent_by_year.to_csv('team_winperc_by_year.csv', index=False)

# %%
clean
# Out:
#                       gameid league  year  game  patch  side position
# 0           8401-8401_game_1    LPL  2022   1.0  12.01  Blue      top  \
# 1           8401-8401_game_1    LPL  2022   1.0  12.01  Blue      jng
# 2           8401-8401_game_1    LPL  2022   1.0  12.01  Blue      mid
# 3           8401-8401_game_1    LPL  2022   1.0  12.01  Blue      bot
# 4           8401-8401_game_1    LPL  2022   1.0  12.01  Blue      sup
# ...                      ...    ...   ...   ...    ...   ...      ...
# 107599  ESPORTSTMNT06/830263    LCK  2019   3.0   8.17   Red      top
# 107600  ESPORTSTMNT06/830263    LCK  2019   3.0   8.17   Red      jng
# 107601  ESPORTSTMNT06/830263    LCK  2019   3.0   8.17   Red      mid
# 107602  ESPORTSTMNT06/830263    LCK  2019   3.0   8.17   Red      bot
# 107603  ESPORTSTMNT06/830263    LCK  2019   3.0   8.17   Red      sup
#
#                  teamname   champion      ban1  ... deaths assists teamkills
# 0               Oh My God       Gwen  Renekton  ...      0       4        13  \
# 1               Oh My God  Jarvan IV  Renekton  ...      1      13        13
# 2               Oh My God     Syndra  Renekton  ...      0       5        13
# 3               Oh My God       Jinx  Renekton  ...      1       6        13
# 4               Oh My God   Nautilus  Renekton  ...      4       7        13
# ...                   ...        ...       ...  ...    ...     ...       ...
# 107599  Team BattleComics      Jayce      Sion  ...      1       6        15
# 107600  Team BattleComics    Camille      Sion  ...      3       4        15
# 107601  Team BattleComics      Galio      Sion  ...      2       6        15
# 107602  Team BattleComics      Xayah      Sion  ...      5       6        15
# 107603  Team BattleComics    Morgana      Sion  ...      4      11        15
#
#        teamdeaths  damagetochampions  wardsplaced  wardskilled
# 0               6            11188.0          7.0          5.0  \
# 1               6             4426.0          7.0         10.0
# 2               6            12577.0          8.0          2.0
# 3               6             9618.0         23.0         12.0
# 4               6             2276.0         34.0          4.0
# ...           ...                ...          ...          ...
# 107599         15            26429.0         13.0          2.0
# 107600         15            10066.0         10.0         15.0
# 107601         15            14097.0         20.0          5.0
# 107602         15            16808.0         11.0         14.0
# 107603         15            10282.0         60.0         14.0
#
#         controlwardsbought  totalgold  total cs
# 0                      3.0     9123.0     172.0
# 1                      5.0     9041.0     145.0
# 2                      4.0     9928.0     212.0
# 3                      7.0    10778.0     199.0
# 4                     13.0     6598.0      22.0
# ...                    ...        ...       ...
# 107599                 3.0    15906.0     323.0
# 107600                10.0    12701.0     178.0
# 107601                 9.0    14502.0     286.0
# 107602                 3.0    14402.0     312.0
# 107603                17.0     9883.0      17.0
#
# [89330 rows x 27 columns]

# %%
champ_wins_by_year = clean.groupby(['champion'])[
    ['result', 'kills', 'deaths', 'assists']].mean().reset_index()
champ_wins_by_year
# Out:
#     champion    result     kills    deaths   assists
# 0     Aatrox  0.482759  2.396890  2.453685  4.068289
# 1       Ahri  0.512476  3.264875  1.869482  6.140115
# 2      Akali  0.534308  3.989876  2.263217  3.968504
# 3     Akshan  0.473684  2.736842  2.789474  3.368421
# 4    Alistar  0.505155  0.677191  3.014175  7.999356
# ..       ...       ...       ...       ...       ...
# 154     Zeri  0.553236  4.446764  1.826722  4.885177
# 155    Ziggs  0.468750  2.432292  2.213542  5.255208
# 156   Zilean  0.503597  1.460432  1.705036  7.115108
# 157      Zoe  0.498914  3.018103  1.763939  4.899348
# 158     Zyra  0.111111  1.222222  3.777778  5.555556
#
# [159 rows x 5 columns]

# %% [markdown]
# ## Build our geo-json dataset
# We want to be able to do the following
# - Teams that win the most in each region
# - Champions that win the most in each region
# - Champions that lose the most in each region

# %%
regional_data = clean.groupby(['gameid', 'league'])[['deaths', 'assists', 'kills', 'damagetochampions', 'wardsplaced', 'wardskilled', 'controlwardsbought', 'totalgold', 'total cs']].sum().reset_index()

# %%
regional_data
# Out:
#                 gameid league  deaths  assists  kills  damagetochampions
# 0            2899-3157    LPL      16       45     16            88856.0  \
# 1            2899-3158    LPL      16       45     16           112750.0
# 2            2899-3159    LPL      32       72     32           149765.0
# 3            2900-3160    LPL      29       63     28           143467.0
# 4            2900-3161    LPL      36       97     36           197290.0
# ...                ...    ...     ...      ...    ...                ...
# 8936  TRLH3/1002720016    LEC      17       52     17            93719.0
# 8937  TRLH3/1002720036    LEC      17       49     17           132822.0
# 8938  TRLH3/1002720046    LEC      28       73     28           151635.0
# 8939  TRLH3/1002720047    LEC      18       49     18           112443.0
# 8940  TRLH3/1002720048    LEC      17       42     17           101834.0
#
#       wardsplaced  wardskilled  controlwardsbought  totalgold  total cs
# 0           242.0         96.0                56.0    97008.0    1913.0
# 1           198.0         66.0                53.0   105411.0    2047.0
# 2           277.0         91.0                87.0   135678.0    2569.0
# 3           379.0        151.0                74.0   134594.0    2570.0
# 4           399.0        159.0                86.0   157946.0    2777.0
# ...           ...          ...                 ...        ...       ...
# 8936        229.0         92.0               101.0   111094.0    2182.0
# 8937        270.0        118.0               111.0   124959.0    2527.0
# 8938        256.0         97.0                97.0   125128.0    2372.0
# 8939        228.0         80.0                73.0   108618.0    2031.0
# 8940        274.0        114.0                93.0   114618.0    2291.0
#
# [8941 rows x 11 columns]

# %% [markdown]
# ## Build our node data
# We want to be able to do the following:
# - champion playrate with each other
# - champion win percentage with each other

# %%
import itertools

# %%
# Create a new DataFrame by grouping the original DataFrame by 'gameid' and 'side'
grouped_df = clean.groupby(['gameid', 'side'])

# Create an empty dictionary to store champion pairs and their counts
champion_pairs = {}
champion_pairs_wins = {}

# Iterate over the grouped DataFrame
for group_name, group_data in grouped_df:

    # Extract the champions in the current group
    champions = group_data['champion'].unique()

    # Generate all possible combinations of champions
    combinations = list(itertools.combinations(champions, 2))

    # Increment the count for each champion pair
    for pair in combinations:
        if pair in champion_pairs:
            champion_pairs[pair] += 1
            champion_pairs_wins[pair] += group_data['result'].iloc[0]
        else:
            champion_pairs[pair] = 1
            champion_pairs_wins[pair] = group_data['result'].iloc[0]

# Create a new DataFrame from the champion_pairs dictionary
champion_pairs_df = pd.DataFrame(champion_pairs.items(), columns=[
                                 'champion_pair', 'count']).sort_values('count', ascending=False)

# Find the champion pair playrate
champion_plays = clean.groupby(['champion'])['side'].count()

def calc_playrate(pair, comb_plays):
    return (comb_plays / (champion_plays[list(pair)].sum() - comb_plays))


# Divide the champion pairs df by the sum of the times each individual champion was played
champion_pairs_df['playrate'] = champion_pairs_df.apply(
    lambda x: calc_playrate(x[0], x[1]), axis=1)

# %%
champion_pairs_df = champion_pairs_df.reset_index(drop=True)
champion_pairs_df.head()
# Out:
#           champion_pair  count  playrate
# 0        (Xayah, Rakan)    653  0.310066
# 1    (Aphelios, Thresh)    500  0.171527
# 2  (Aphelios, Nautilus)    381  0.105278
# 3   (Varus, Tahm Kench)    353  0.113105
# 4     (Kai'Sa, Alistar)    341  0.114200

# %%
champion_pair_wins = pd.DataFrame(champion_pairs_wins.items(), columns=[
    'champion_pair', 'wins']).sort_values('wins', ascending=False)
node_data = pd.merge(champion_pairs_df, champion_pair_wins,
                     how='left', on='champion_pair')
node_data[['champ1', 'champ2']
          ] = node_data['champion_pair'].apply(pd.Series)

# %%
node_data[node_data.columns[1:]].to_csv('node_data.csv', index=False)
